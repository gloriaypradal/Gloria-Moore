# %% [markdown]
# <a href="https://colab.research.google.com/github/gloriaypradal/Gloria-Moore/blob/main/Audits_ATV1_06_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("audits2022.csv")

# %%
data.head()
# Out:
#         TimeStamp LineName      Inspector 1. What model?  \
# 0  1/3/2022 11:25     ATV1  Michael Shoup   RFT00A/B/C/D
# 1  1/3/2022 11:49     ATV1  Michael Shoup   RFT00A/B/C/D
# 2  1/3/2022 13:39     ATV1  Michael Shoup   RFT00A/B/C/D
# 3  1/4/2022 13:20     ATV1  Michael Shoup   RFT00A/B/C/D
# 4  1/4/2022 13:20     ATV1  Michael Shoup   RFT00A/B/C/D
#
#                                            2. Defect  \
# 0  Rivets for rubber mat cover for master cylinde...
# 1                 Control lever set too low n guide.
# 2                      Left side of hood was warped.
# 3                             Left door screw loose.
# 4  Coolant clamp at thermostat was over the stopper.
#
#   3. Responsible Work Station  4. Quantity Bad     5. Defect Code  \
# 0                        A07L                1        Loose Parts
# 1                        A11L                1  Incorrect Process
# 2                        A24R                1       Vendor Issue
# ...

# %%
data.describe(include="O")
# Out:
#              TimeStamp LineName   Inspector 1. What model?  \
# count              763      763         763            763
# unique             742        1           5              4
# top     1/4/2022 13:20     ATV1  Josh Meier   RFT00A/B/C/D
# freq                 3      763         388            758
#
#                  2. Defect 3. Responsible Work Station     5. Defect Code  \
# count                  763                         752                763
# unique                 720                         162                 10
# top     Bubbles in decals.                        A24L  Incorrect Process
# freq                     6                          22                310
#
#               6. Who Notified? 7. Units checked 8. Countermeasure  \
# count                      762              760               760
# unique                      19                3                51
# top     Production Team Leader     Before/After             Fixed
# ...

# %%
data3 = data['3. Responsible Work Station'].unique()

# %%
data3
# Out:
# array(['A07L', 'A11L', 'A24R', 'A26L', 'A04R', 'A25L', 'A15R', 'A06R',
#        'A25R', 'A19L', 'A15L', 'A10R', 'A28L', 'A14L', 'A32R', 'A13R',
#        'A36L', 'A05R', 'A32L', 'A21L', 'A02L', 'A03R', 'A24L', 'Welding',
#        'A10L', 'A09R', 'A12R', 'A02R', 'A18L', 'A22L', 'A15Rm', 'A20L',
#        'A09L', 'A22R', 'A26R', 'A06L', 'A30R', 'A29R', 'A16L', 'A01R',
#        'A10LB', 'A07R', 'A04Lb', 'A08L', 'A33L', 'A30L', 'A29L', '18R',
#        '30R', '15R', '15L & R', '2R', '23R', '7L', nan, '5R', '14L',
#        '12R', '8R', '23L', '26', 'a25r', 'a08l', 'a10r', '22R', 'a26r',
#        'A18R', '26R', '2L', '11L', 'Ao2R', 'O2L', 'a02r', 'A24', '25R',
#        'a26l', '15L', 'a35', 'a11l', 'a15r', 'Paint', '25L', 'unknown',
#        '13L', 'a03r', 'a09l', 'A32', 'a16r', '1R', '9R', '17L', 'A12L',
#        '24L', '9L', 'a06l', 'A23L', 'A17R', 'a22r', 'a32', 'a28l', 'A30',
#        'A01L', 'a21l', 'a24l', '4R', 'A27R', 'A18', 'A01', 'A22', 'A11',
# ...

# %%
data['3. Responsible Work Station']=data['3. Responsible Work Station'].str.upper()

# %%
data1 = data.groupby('3. Responsible Work Station').count()

# %%
fig = plt.figure(figsize=(30,9))
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=15)
plt.title("Number of Defects by Work Station", fontsize=20)
ax.bar(data1.index,data1['2. Defect'])
# Out:
# <BarContainer object of 144 artists>

# %%
data2 = data1.sort_values(by='2. Defect', ascending=False)

# %%
fig = plt.figure(figsize=(30,9))
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=15)
plt.title("Number of Defects by Work Station", fontsize=20)
ax.bar(data2.index,data2['2. Defect'], color = "red", alpha = 0.6)
# Out:
# <BarContainer object of 144 artists>

# %%
data2.head(10)
# Out:
#                              TimeStamp  LineName  Inspector  1. What model?  \
# 3. Responsible Work Station
# A24L                                23        23         23              23
# A25R                                21        21         21              21
# A02R                                20        20         20              20
# A28L                                18        18         18              18
# A26L                                17        17         17              17
# A26R                                17        17         17              17
# A11L                                17        17         17              17
# A15R                                16        16         16              16
# A22R                                16        16         16              16
# A25L                                16        16         16              16
#
#                              2. Defect  4. Quantity Bad  5. Defect Code  \
# 3. Responsible Work Station
# ...

# %%
data["TimeStamp"] = pd.to_datetime(data["TimeStamp"])

# %%
data.head()
# Out:
#             TimeStamp LineName      Inspector 1. What model?  \
# 0 2022-01-03 11:25:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 1 2022-01-03 11:49:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 2 2022-01-03 13:39:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 3 2022-01-04 13:20:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 4 2022-01-04 13:20:00     ATV1  Michael Shoup   RFT00A/B/C/D
#
#                                            2. Defect  \
# 0  Rivets for rubber mat cover for master cylinde...
# 1                 Control lever set too low n guide.
# 2                      Left side of hood was warped.
# 3                             Left door screw loose.
# 4  Coolant clamp at thermostat was over the stopper.
#
#   3. Responsible Work Station  4. Quantity Bad     5. Defect Code  \
# 0                        A07L                1        Loose Parts
# 1                        A11L                1  Incorrect Process
# 2                        A24R                1       Vendor Issue
# ...

# %%
data['Month'] = pd.DatetimeIndex(data['TimeStamp']).month

# %%
data.head()
# Out:
#             TimeStamp LineName      Inspector 1. What model?  \
# 0 2022-01-03 11:25:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 1 2022-01-03 11:49:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 2 2022-01-03 13:39:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 3 2022-01-04 13:20:00     ATV1  Michael Shoup   RFT00A/B/C/D
# 4 2022-01-04 13:20:00     ATV1  Michael Shoup   RFT00A/B/C/D
#
#                                            2. Defect  \
# 0  Rivets for rubber mat cover for master cylinde...
# 1                 Control lever set too low n guide.
# 2                      Left side of hood was warped.
# 3                             Left door screw loose.
# 4  Coolant clamp at thermostat was over the stopper.
#
#   3. Responsible Work Station  4. Quantity Bad     5. Defect Code  \
# 0                        A07L                1        Loose Parts
# 1                        A11L                1  Incorrect Process
# 2                        A24R                1       Vendor Issue
# ...

# %%
data4 = data.groupby('Month').count()

# %%
data4.head()
# Out:
#        TimeStamp  LineName  Inspector  1. What model?  2. Defect  \
# Month
# 1             52        52         52              52         52
# 2            111       111        111             111        111
# 3            271       271        271             271        271
# 4            174       174        174             174        174
# 5            130       130        130             130        130
#
#        3. Responsible Work Station  4. Quantity Bad  5. Defect Code  \
# Month
# 1                               52               52              52
# 2                              111              111             111
# 3                              262              271             271
# 4                              172              174             174
# 5                              130              130             130
#
#        6. Who Notified?  7. Units checked  8. Countermeasure  9. Comments
# Month
# ...

# %%
fig = plt.figure(figsize=(30,9))
ax = fig.add_axes([0,0,1,1])
plt.xticks(rotation=0, fontsize=20)
plt.yticks(fontsize=15)
plt.title("Number of Defects by Month", fontsize=20)
ax.bar(data4.index,data4['2. Defect'])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # New Section

# %%
data_aud=pd.read_csv("audit_pass_2022.csv")

# %%
data_aud.head()
# Out:
#         TimeStamp LineName      Inspector 1. What Model?  \
# 0  1/3/2022 11:26     ATV1  Michael Shoup         RFT00A
# 1  1/3/2022 13:36     ATV1  Michael Shoup         RFT00B
# 2  1/3/2022 15:28     ATV1  Michael Shoup         RFT00C
# 3   1/4/2022 7:51     ATV1  Michael Shoup         RFT00C
# 4   1/4/2022 9:15     ATV1  Michael Shoup         RFT00A
#
#    2. What Spec Number? 3. What Spec Letter?  4. VIN/HIN Number  \
# 0                   251                    D  JKARFCA17NB515386
# 1                   251                    B  JKARFCB18NB502726
# 2                   251                    B  JKARFCC16NB501301
# 3                   251                    B  JKARFCC18NB501302
# 4                   255                    D  JKARFCA10NB515407
#
#   5. Inspection Results 6. Type of Failure  \
# 0                  Pass                NaN
# 1                  Pass                NaN
# 2                  Pass                NaN
# 3                  Pass                NaN
# ...

# %%
data_aud['Month'] = pd.DatetimeIndex(data_aud['TimeStamp']).month

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# make subplots
fig, axes = plt.subplots(nrows = 2, ncols = 2)

# make the data read to feed into the visulizer
X_Pass = data_aud.groupby('5. Inspection Results').size().reset_index(name='Counts')['5. Inspection Results']
Y_Pass = data_aud.groupby('5. Inspection Results').size().reset_index(name='Counts')['Counts']


axes[0, 0].bar(X_Pass, Y_Pass)
axes[0, 0].set_title('Pass / Fail Audits', fontsize=25)
axes[0, 0].set_ylabel('Counts', fontsize=20)
axes[0, 0].tick_params(axis='both', labelsize=15)



Month_pass = data[data['5. Inspection Results']==1]['Month'].value_counts()
Month_Fail = data.replace({'is_canceled': {1: 'yes', 0: 'no'}})[data['is_canceled']==0]['arrival_date_month'].value_counts()
Month_Fail = Arrival_not_canceled.reindex(index = Arrival_canceled.index)


p5 = axes[1, 0].bar(Arrival_canceled.index, Arrival_canceled.values)
p6 = axes[1, 0].bar(Arrival_not_canceled.index, Arrival_not_canceled.values, bottom=Arrival_canceled.values, )
axes[1, 0].set_title('Arrival Month', fontsize=25)
axes[1, 0].set_ylabel('Counts', fontsize=20)
axes[1, 0].tick_params(axis='y', labelsize=15)
axes[1, 0].tick_params(axis='x', labelsize=15, rotation = 45)
axes[1, 0].legend((p5[0], p6[0]), ('Canceled', 'Not Canceled'), fontsize = 15)

plt.show()
